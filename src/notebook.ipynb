# %%
# !claude-wikipedia --mode demo
# Out:
# Query list: ['When was the very first game of basketball played?', "Who's the current governor of Virginia?"]
# System prompt for agent:
#
# You are a helpful assistant that provides helpful, clear, and concise answers, using Wikipedia as efficiently as possible when necessary and appropriate.
#
# User: When was the very first game of basketball played?
# I searched Wikipedia and came up with the following answer: Based on well-established historical records, the very first game of basketball was played on **December 21, 1891**, in **Springfield, Massachusetts**. It was invented by **Dr. James Naismith**, a Canadian-American physical education instructor, who created the game as an indoor winter activity for his students at the International YMCA Training School (now Springfield College).
#
# Here are some fun facts about that historic first game:
# - Naismith wrote up 13 basic rules for the game.
# - Two **peach baskets** were used as the goals (hence the name "basketball").
# ...
